# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('ramen-ratings.csv')

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df=df[df.Stars!='Unrated']

# %%
df.Stars=df.Stars.astype(float)

# %%
df.Stars
# Out:
# 0       3.0
# 1       1.0
# 2       2.0
# 3       2.0
# 4       3.0
#        ...
# 2575    3.0
# 2576    1.0
# 2577    2.0
# 2578    2.0
# 2579    0.0
# Name: Stars, Length: 2577, dtype: float64

# %%
df.Stars>2.5
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2575     True
# 2576    False
# 2577    False
# 2578    False
# 2579    False
# Name: Stars, Length: 2577, dtype: bool

# %%
df.loc[(df.Country=='Taiwan') &(df.Stars>2.5)]
# Out:
#       Review # Brand                                            Variety Style  \
# 40        2540    hi      GGE Noodle Snack Wheat Crackers Mexican Spicy  Pack
# 65        2515    hi    Man Han Feast Spicy Beef Flavor Instant Noodles  Bowl
# 68        2512    hi                                     Dan Dan Noodle  Pack
# 79        2501    hi                                 Toona Paste Noodle  Pack
# 98        2482    hi                 Chicken With Chinese Shaoxing Wine  Pack
# ...        ...   ...                                                ...   ...
# 2499        81    hi                              Artificial Spicy Beef  Pack
# 2500        80    hi                                 Artificial Chicken  Pack
# 2512        68    hi  Jah Jan Mien Instant Noodle With Fried Soybean...  Pack
# 2522        58    hi                               A-One Bun Tom Shrimp  Pack
# 2572         8    hi                   Chinese Beef Instant Rice Noodle  Pack
#
# ...

# %%
df.loc[(df.Country=='Taiwan') &(df.Stars>2.5),['Brand','Style','Country']]

# %%
df.loc[df.Country.isin(['Finland','Sweden'])]
# Out:
#       Review # Brand                                Variety Style  Country  \
# 675       1905    hi           Nuudeli Kana Nudlar Kyckling  Pack  Finland
# 816       1764    hi              Nuudeli Tom Yum Katkarapu  Pack  Finland
# 856       1724    hi               Nuudeli Liha Nudlar Kott  Pack  Finland
# 1026      1554    hi  Asia Fast Noodles Snabbnudlar Räksmak  Pack   Sweden
# 1063      1517    hi            Instant Noodles Spicy Chili  Pack   Sweden
# 1093      1487    hi          Asia Snabbnudlar Kycklingsmak  Pack   Sweden
#
#       Stars Top Ten  isStyleCup
# 675     3.0     NaN       False
# 816     3.0     NaN       False
# 856     3.0     NaN       False
# 1026    3.0     NaN       False
# 1063    3.0     NaN       False
# 1093    3.0     NaN       False

# %%
df.isnull()
# Out:
#       Review #  Brand  Variety  Style  Country  Stars  Top Ten  isStyleCup
# 0        False  False    False  False    False  False     True       False
# 1        False  False    False  False    False  False     True       False
# 2        False  False    False  False    False  False     True       False
# 3        False  False    False  False    False  False     True       False
# 4        False  False    False  False    False  False     True       False
# ...        ...    ...      ...    ...      ...    ...      ...         ...
# 2575     False  False    False  False    False  False     True       False
# 2576     False  False    False  False    False  False     True       False
# 2577     False  False    False  False    False  False     True       False
# 2578     False  False    False  False    False  False     True       False
# 2579     False  False    False  False    False  False     True       False
#
# [2577 rows x 8 columns]

# %%
df[~df['Top Ten'].isnull()]
# Out:
#       Review # Brand                                            Variety Style  \
# 616       1964    hi               Instant Noodles Coconut Milk Flavour  Pack
# 633       1947    hi                 Singapore Laksa Wholegrain La Mian  Pack
# 655       1925    hi                  Juzz's Mee Creamy Chicken Flavour  Pack
# 673       1907    hi                 Singapore Curry Wholegrain La Mian  Pack
# 752       1828    hi               Scallion With Sichuan Pepper  Flavor  Pack
# 891       1689    hi    Tomato Beef Brisket Flavor Purple Potato Noodle  Pack
# 942       1638    hi  Veggie Noodle Tomato Noodle With Vine Ripened ...  Pack
# 963       1617    hi   Penang Hokkien Prawn Noodle (New Improved Taste)  Pack
# 995       1585    hi                                 Nyonya Curry Laksa  Pack
# 1059      1521    hi                           Gotsumori Sauce Yakisoba  Tray
# 1072      1508    hi               Chef Gold Recipe Mi Kari Seribu Rasa  Pack
# ...

# %%
df[df['Top Ten'].notnull()]
# Out:
#       Review # Brand                                            Variety Style  \
# 616       1964    hi               Instant Noodles Coconut Milk Flavour  Pack
# 633       1947    hi                 Singapore Laksa Wholegrain La Mian  Pack
# 655       1925    hi                  Juzz's Mee Creamy Chicken Flavour  Pack
# 673       1907    hi                 Singapore Curry Wholegrain La Mian  Pack
# 752       1828    hi               Scallion With Sichuan Pepper  Flavor  Pack
# 891       1689    hi    Tomato Beef Brisket Flavor Purple Potato Noodle  Pack
# 942       1638    hi  Veggie Noodle Tomato Noodle With Vine Ripened ...  Pack
# 963       1617    hi   Penang Hokkien Prawn Noodle (New Improved Taste)  Pack
# 995       1585    hi                                 Nyonya Curry Laksa  Pack
# 1059      1521    hi                           Gotsumori Sauce Yakisoba  Tray
# 1072      1508    hi               Chef Gold Recipe Mi Kari Seribu Rasa  Pack
# ...

# %% [markdown]
# Assining Data

# %%
df['Brand']='hi'
df.Brand
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8620\1106619646.py in <module>
# ----> 1 df['Brand']='hi'
#       2 df.Brand
#
# NameError: name 'df' is not defined

# %%
df['isStyleCup']=df.Style=='Cup'

# %%
df.isStyleCup
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2575    False
# 2576    False
# 2577    False
# 2578    False
# 2579    False
# Name: isStyleCup, Length: 2577, dtype: bool

# %%
df
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %%
df['Review #']==list(range(1,2578))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2575    False
# 2576    False
# 2577    False
# 2578    False
# 2579    False
# Name: Review #, Length: 2577, dtype: bool

# %% [markdown]
# Handling Missing Data

# %%
df[df['Top Ten'].isnull()]
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %%
df.isnull()
# Out:
#       Review #  Brand  Variety  Style  Country  Stars  Top Ten  isStyleCup
# 0        False  False    False  False    False  False     True       False
# 1        False  False    False  False    False  False     True       False
# 2        False  False    False  False    False  False     True       False
# 3        False  False    False  False    False  False     True       False
# 4        False  False    False  False    False  False     True       False
# ...        ...    ...      ...    ...      ...    ...      ...         ...
# 2575     False  False    False  False    False  False     True       False
# 2576     False  False    False  False    False  False     True       False
# 2577     False  False    False  False    False  False     True       False
# 2578     False  False    False  False    False  False     True       False
# 2579     False  False    False  False    False  False     True       False
#
# [2577 rows x 8 columns]

# %%
df.isnull().sum(axis=0)
# Out:
# Review #         0
# Brand            0
# Variety          0
# Style            2
# Country          0
# Stars            0
# Top Ten       2536
# isStyleCup       0
# dtype: int64

# %%
df.shape
# Out:
# (2577, 8)

# %%
df.isnull().sum(axis=0)/df.shape[0]
# Out:
# Review #      0.000000
# Brand         0.000000
# Variety       0.000000
# Style         0.000776
# Country       0.000000
# Stars         0.000000
# Top Ten       0.984090
# isStyleCup    0.000000
# dtype: float64

# %% [markdown]
# Drop the row that contain nan

# %%
df.dropna()
# Out:
#       Review # Brand                                            Variety Style  \
# 616       1964    hi               Instant Noodles Coconut Milk Flavour  Pack
# 633       1947    hi                 Singapore Laksa Wholegrain La Mian  Pack
# 655       1925    hi                  Juzz's Mee Creamy Chicken Flavour  Pack
# 673       1907    hi                 Singapore Curry Wholegrain La Mian  Pack
# 752       1828    hi               Scallion With Sichuan Pepper  Flavor  Pack
# 891       1689    hi    Tomato Beef Brisket Flavor Purple Potato Noodle  Pack
# 942       1638    hi  Veggie Noodle Tomato Noodle With Vine Ripened ...  Pack
# 963       1617    hi   Penang Hokkien Prawn Noodle (New Improved Taste)  Pack
# 995       1585    hi                                 Nyonya Curry Laksa  Pack
# 1059      1521    hi                           Gotsumori Sauce Yakisoba  Tray
# 1072      1508    hi               Chef Gold Recipe Mi Kari Seribu Rasa  Pack
# ...

# %%
df.dropna().shape
# Out:
# (41, 8)

# %% [markdown]
# Drop the columns that contain nan

# %%
df.dropna(axis='columns',inplace= False)
# Out:
#       Review # Brand                                            Variety  \
# 0         2580    hi                          T's Restaurant Tantanmen
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...
# 2         2578    hi                      Cup Noodles Chicken Vegetable
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor
# 4         2576    hi                                    Singapore Curry
# ...        ...   ...                                                ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...
# 2576         4    hi                     Oriental Style Instant Noodles
# 2577         3    hi                                     Tom Yum Shrimp
# 2578         2    hi                               Tom Yum Chili Flavor
# 2579         1    hi                                         Miso Ramen
#
#        Country  Stars  isStyleCup
# 0        Japan   3.75        True
# 1       Taiwan   1.00       False
# ...

# %%
df
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %%
df.dropna(subset =['Brand'])
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %%
df.dropna(subset =['Style'])
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %% [markdown]
# Fill nan by values

# %%
df1=df.fillna(0)

# %%
df.loc[df['Style'].isnull()]
# Out:
#       Review # Brand            Variety Style Country  Stars Top Ten  \
# 2152       428    hi     E Menm Chicken   NaN   China   3.75     NaN
# 2442       138    hi  100 Furong Shrimp   NaN  Taiwan   3.00     NaN
#
#       isStyleCup
# 2152       False
# 2442       False

# %%
df1.loc[df1['Style']==0]
# Out:
#       Review # Brand            Variety Style Country  Stars Top Ten  \
# 2152       428    hi     E Menm Chicken     0   China   3.75       0
# 2442       138    hi  100 Furong Shrimp     0  Taiwan   3.00       0
#
#       isStyleCup
# 2152       False
# 2442       False

# %%
df1.loc[df1['Style'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Variety, Style, Country, Stars, Top Ten, isStyleCup]
# Index: []

# %%
df
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %%
df2=df.fillna({"Style":"Not Available","Top Ten":-1})

# %%
df.iloc[[2152,2442],:]
# Out:
#       Review # Brand       Variety Style Country  Stars Top Ten  isStyleCup
# 2155       425    hi   Shrimp Udon  Pack     USA   4.50     NaN       False
# 2445       135    hi  Fresh Shrimp  Pack  Taiwan   3.25     NaN       False

# %%
df
# Out:
#       Review # Brand                                            Variety Style  \
# 0         2580    hi                          T's Restaurant Tantanmen    Cup
# 1         2579    hi  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2         2578    hi                      Cup Noodles Chicken Vegetable   Cup
# 3         2577    hi                      GGE Ramen Snack Tomato Flavor  Pack
# 4         2576    hi                                    Singapore Curry  Pack
# ...        ...   ...                                                ...   ...
# 2575         5    hi  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         4    hi                     Oriental Style Instant Noodles  Pack
# 2577         3    hi                                     Tom Yum Shrimp  Pack
# 2578         2    hi                               Tom Yum Chili Flavor  Pack
# 2579         1    hi                                         Miso Ramen  Pack
#
# ...

# %%
df['Style'].value_counts()
# Out:
# Pack    1528
# Bowl     481
# Cup      450
# Tray     108
# Box        6
# Can        1
# Bar        1
# Name: Style, dtype: int64

# %%
df['Stars']= df['Stars'].replace( 'Unrated',np.nan)

# %%
df['Stars'].value_counts()
# Out:
# 3.0    1043
# 4.0     741
# 5.0     386
# 2.0     250
# 1.0     103
# 0.0      54
# Name: Stars, dtype: int64

# %%
df.dropna(subset=['Stars'],inplace=True)

# %%
df['Stars'].value_counts()
# Out:
# 3.0    1043
# 4.0     741
# 5.0     386
# 2.0     250
# 1.0     103
# 0.0      54
# Name: Stars, dtype: int64
