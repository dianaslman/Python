# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv('car_sales.csv')

# %%
ds.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25  Driver & Passenger  ...          5    195
# 2        20           26         Driver only  ...          5    180
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# ...

# %%
ds
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0            1        Acura  Integra    Small       12.9   15.9       18.8
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2            3         Audi       90  Compact       25.9   29.1       32.3
# 3            4         Audi      100  Midsize       30.8   37.7       44.6
# 4            5          BMW     535i  Midsize       23.7   30.0       36.2
# ..         ...          ...      ...      ...        ...    ...        ...
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 89          90   Volkswagen   Passat  Compact       17.6   20.0       22.4
# 90          91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 91          92        Volvo      240  Compact       21.8   22.7       23.5
# 92          93        Volvo      850  Midsize       24.8   26.7       28.5
#
# ...

# %%
ds.describe()
# Out:
#        Unnamed: 0  Min.Price      Price  Max.Price   MPG.city  MPG.highway  \
# count   93.000000  93.000000  93.000000  93.000000  93.000000    93.000000
# mean    47.000000  17.125806  19.509677  21.898925  22.365591    29.086022
# std     26.990739   8.746029   9.659430  11.030457   5.619812     5.331726
# min      1.000000   6.700000   7.400000   7.900000  15.000000    20.000000
# 25%     24.000000  10.800000  12.200000  14.700000  18.000000    26.000000
# 50%     47.000000  14.700000  17.700000  19.600000  21.000000    28.000000
# 75%     70.000000  20.300000  23.300000  25.300000  25.000000    31.000000
# max     93.000000  45.400000  61.900000  80.000000  46.000000    50.000000
#
#        EngineSize  Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  \
# count   93.000000   93.000000    93.000000     93.000000           93.000000
# mean     2.667742  143.827957  5280.645161   2332.204301           16.664516
# ...

# %%
ds['Price'].max()
# Out:
# 61.9

# %%
ds_1=ds.set_index("Unnamed: 0")
ds_1
# Out:
#            Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# Unnamed: 0
# 1                 Acura  Integra    Small       12.9   15.9       18.8
# 2                 Acura   Legend  Midsize       29.2   33.9       38.7
# 3                  Audi       90  Compact       25.9   29.1       32.3
# 4                  Audi      100  Midsize       30.8   37.7       44.6
# 5                   BMW     535i  Midsize       23.7   30.0       36.2
# ...                 ...      ...      ...        ...    ...        ...
# 89           Volkswagen  Eurovan      Van       16.6   19.7       22.7
# 90           Volkswagen   Passat  Compact       17.6   20.0       22.4
# 91           Volkswagen  Corrado   Sporty       22.9   23.3       23.7
# 92                Volvo      240  Compact       21.8   22.7       23.5
# 93                Volvo      850  Midsize       24.8   26.7       28.5
#
#             MPG.city  MPG.highway             AirBags DriveTrain  ...  \
# ...

# %%
ds.loc[(ds.Manufacturer=='Volkswagen') &(ds.Price>4),['Model','Length','Width']]
# Out:
#       Model  Length  Width
# 87      Fox     163     63
# 88  Eurovan     187     72
# 89   Passat     180     67
# 90  Corrado     159     66

# %%
ds.loc[ds.Model.isin(['Eurovan','Legend'])]
# Out:
#     Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 1            2        Acura   Legend  Midsize       29.2   33.9       38.7
# 88          89   Volkswagen  Eurovan      Van       16.6   19.7       22.7
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 1         18           25  Driver & Passenger  ...          5    195
# 88        17           21                None  ...          7    187
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 1         115     71           38            30.0         15.0    3560
# 88        115     72           38            34.0          NaN    3960
#
#      Origin                Make
# 1   non-USA        Acura Legend
# 88  non-USA  Volkswagen Eurovan
#
# [2 rows x 28 columns]

# %%
mean=np.mean(Price)
plt.hist(Price, bins=bins,  edgecolor='black')
plt.axvline(mean,color='yellow',linewidth=1)
plt.xlabel('Length')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10480\872844481.py in <module>
# ----> 1 mean=np.mean(Price)
#       2 plt.hist(Price, bins=bins,  edgecolor='black')
#       3 plt.axvline(mean,color='yellow',linewidth=1)
#       4 plt.xlabel('Length')
#       5 plt.ylabel('Price')
#
# NameError: name 'Price' is not defined

# %%
ds.isnull()

# %%
ds.shape

# %%
ds['Origin'].value_counts()

# %%
ds[(ds['Luggage.room'].isnull())&(ds.Make=='Volkswagen Eurovan')]

# %%
ds.Price.max()-ds.Price.min()

# %%
ds.groupby('Origin')['Price'].min().reset_index()

# %%
ds.groupby('Manufacturer')['Wheelbase'].max().reset_index()

# %%
ds.groupby('Length')['Passengers'].count().reset_index()

# %%
ds.groupby('Width')['Rear.seat.room'].mean().reset_index()
