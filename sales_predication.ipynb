# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#    Taxi_dist  Market_dist  Hospital_dist  Carpet_area  Builtup_area  \
# 0     9796.0       5250.0        10703.0       1659.0        1961.0
# 1     8294.0       8186.0        12694.0       1461.0        1752.0
# 2    11001.0      14399.0        16991.0       1340.0        1609.0
# 3     8301.0      11188.0        12289.0       1451.0        1748.0
# 4    10510.0      12629.0        13921.0       1770.0        2111.0
#
#    Parking_type City_type  Rainfall  Price_house
# 0          Open     CAT B       530      6649000
# 1  Not Provided     CAT B       210      3982000
# 2  Not Provided     CAT A       720      5401000
# 3       Covered     CAT B       620      5373000
# 4  Not Provided     CAT B       450      4662000

# %%
df.describe()
# Out:
#           Taxi_dist   Market_dist  Hospital_dist   Carpet_area  Builtup_area  \
# count    919.000000    919.000000     931.000000    924.000000    917.000000
# mean    8229.727965  11018.752992   13072.092374   1511.862554   1794.924755
# std     2561.985008   2543.920590    2586.456161    790.969660    468.159457
# min      146.000000   1666.000000    3227.000000    775.000000    932.000000
# 25%     6476.000000   9354.500000   11301.500000   1318.000000   1583.000000
# 50%     8230.000000  11161.000000   13163.000000   1480.500000   1774.000000
# 75%     9937.000000  12670.500000   14817.000000   1655.000000   1982.000000
# max    20662.000000  20945.000000   23294.000000  24300.000000  12730.000000
#
#           Rainfall   Price_house
# count   932.000000  9.320000e+02
# mean    785.579399  6.084695e+06
# std     265.546853  5.025364e+06
# min    -110.000000  3.000000e+04
# 25%     600.000000  4.658000e+06
# 50%     780.000000  5.866000e+06
# 75%     970.000000  7.187250e+06
# ...

# %%
df['Rainfall'].mean()
# Out:
# 785.5793991416309

# %%
df[['Rainfall','Taxi_dist']].mean()
# Out:
# Rainfall      785.579399
# Taxi_dist    8229.727965
# dtype: float64

# %%
df.groupby('Market_dist').mean()
# Out:
#              Taxi_dist  Hospital_dist  Carpet_area  Builtup_area  Rainfall  \
# Market_dist
# 1666.0           146.0         3227.0       1072.0        1296.0     900.0
# 4402.0          4049.0         8614.0       1948.0        2374.0     930.0
# 4574.0          5097.0         9365.0       1449.0        1733.0     320.0
# 4644.0          6486.0         9312.0       1330.0        1606.0     590.0
# 4950.0          1648.0         6583.0        932.0        1138.0     820.0
# ...                ...            ...          ...           ...       ...
# 17541.0        12794.0        20046.0       1440.0        1733.0    1120.0
# 17552.0        11986.0        19014.0       1638.0        1952.0     690.0
# 17958.0        11304.0        19046.0       1648.0        1959.0     370.0
# 18281.0         9308.0        18532.0       1771.0        2147.0     430.0
# 20945.0        20662.0        23294.0      24300.0       12730.0    1130.0
#
#              Price_house
# Market_dist
# ...

# %%
df.groupby('Price_house')[['Builtup_area','Carpet_area']].mean().reset_index()
# Out:
#      Price_house  Builtup_area  Carpet_area
# 0          30000           NaN          NaN
# 1        1492000        1508.0       1250.0
# 2        1637000        1790.0       1477.0
# 3        1767000        1877.0       1537.0
# 4        2027000        1946.0       1624.0
# ..           ...           ...          ...
# 844     10231000        1587.0       1303.0
# 845     10292000        1638.0       1365.0
# 846     10515000        2104.0       1775.0
# 847     11632000        2414.0       1989.0
# 848    150000000       12730.0      24300.0
#
# [849 rows x 3 columns]

# %% [markdown]
# Aggregation Function
#
# count() Total number of items
#
# first(),last()  First and Last item
#
# min(),max Min and Max item
#
# mean(),medain() mean and medain item
#
# std(),var() Standard devaition and variance
#
# mad() mean absolute divation
#
# prod() product of all items
#
# sum()  Sum of all items

# %%
for (Market_dist,group) in df.groupby('Market_dist'):
    print(Market_dist,group)
# Out:
# 1666.0      Taxi_dist  Market_dist  Hospital_dist  Carpet_area  Builtup_area  \
# 854      146.0       1666.0         3227.0       1072.0        1296.0
#
#     Parking_type City_type  Rainfall  Price_house
# 854         Open     CAT C       900      4759000
# 4402.0      Taxi_dist  Market_dist  Hospital_dist  Carpet_area  Builtup_area  \
# 423     4049.0       4402.0         8614.0       1948.0        2374.0
#
#     Parking_type City_type  Rainfall  Price_house
# 423         Open     CAT A       930      8954000
# 4574.0      Taxi_dist  Market_dist  Hospital_dist  Carpet_area  Builtup_area  \
# 766     5097.0       4574.0         9365.0       1449.0        1733.0
#
#     Parking_type City_type  Rainfall  Price_house
# 766      Covered     CAT C       320      6006000
# 4644.0      Taxi_dist  Market_dist  Hospital_dist  Carpet_area  Builtup_area  \
# 866     6486.0       4644.0         9312.0       1330.0        1606.0
#
#     Parking_type City_type  Rainfall  Price_house
# ...
