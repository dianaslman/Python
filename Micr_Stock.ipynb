# %%
import numpy as np
import pandas as pd
import matplotlib as plot
import seaborn as sns

# %%
df=pd.read_csv('Microsoft_Stock.csv')

# %%
df.head()
# Out:
#                 Date   Open   High    Low  Close    Volume
# 0  4/1/2015 16:00:00  40.60  40.76  40.31  40.72  36865322
# 1  4/2/2015 16:00:00  40.66  40.74  40.12  40.29  37487476
# 2  4/6/2015 16:00:00  40.34  41.78  40.18  41.55  39223692
# 3  4/7/2015 16:00:00  41.61  41.91  41.31  41.53  28809375
# 4  4/8/2015 16:00:00  41.48  41.69  41.04  41.42  24753438

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1511.000000  1511.000000  1511.000000  1511.000000  1.511000e+03
# mean    107.385976   108.437472   106.294533   107.422091  3.019863e+07
# std      56.691333    57.382276    55.977155    56.702299  1.425266e+07
# min      40.340000    40.740000    39.720000    40.290000  1.016120e+05
# 25%      57.860000    58.060000    57.420000    57.855000  2.136213e+07
# 50%      93.990000    95.100000    92.920000    93.860000  2.662962e+07
# 75%     139.440000   140.325000   137.825000   138.965000  3.431962e+07
# max     245.030000   246.130000   242.920000   244.990000  1.352271e+08

# %%
df.shape
# Out:
# (1511, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1511 non-null   object
#  1   Open    1511 non-null   float64
#  2   High    1511 non-null   float64
#  3   Low     1511 non-null   float64
#  4   Close   1511 non-null   float64
#  5   Volume  1511 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 71.0+ KB

# %%
#df['Date']=pd.to_datetime(df['Date'],format='%m/%d/%y  %H:%M:%S')

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['DayWeek']=df.loc[0,'Date'].day_name()

# %%
df['DayWeek']
# Out:
# 0       Wednesday
# 1       Wednesday
# 2       Wednesday
# 3       Wednesday
# 4       Wednesday
#           ...
# 1506    Wednesday
# 1507    Wednesday
# 1508    Wednesday
# 1509    Wednesday
# 1510    Wednesday
# Name: DayWeek, Length: 1511, dtype: object

# %%
df
# Out:
#                     Date    Open    High     Low   Close    Volume    DayWeek
# 0    2015-04-01 16:00:00   40.60   40.76   40.31   40.72  36865322  Wednesday
# 1    2015-04-02 16:00:00   40.66   40.74   40.12   40.29  37487476  Wednesday
# 2    2015-04-06 16:00:00   40.34   41.78   40.18   41.55  39223692  Wednesday
# 3    2015-04-07 16:00:00   41.61   41.91   41.31   41.53  28809375  Wednesday
# 4    2015-04-08 16:00:00   41.48   41.69   41.04   41.42  24753438  Wednesday
# ...                  ...     ...     ...     ...     ...       ...        ...
# 1506 2021-03-25 16:00:00  235.30  236.94  231.57  232.34  34061853  Wednesday
# 1507 2021-03-26 16:00:00  231.55  236.71  231.55  236.48  25479853  Wednesday
# 1508 2021-03-29 16:00:00  236.59  236.80  231.88  235.24  25227455  Wednesday
# 1509 2021-03-30 16:00:00  233.53  233.85  231.10  231.85  24792012  Wednesday
# 1510 2021-03-31 16:00:00  232.91  239.10  232.39  235.77  43623471  Wednesday
#
# [1511 rows x 7 columns]

# %%
df['Date'].min()
# Out:
# Timestamp('2015-04-01 16:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2021-03-31 16:00:00')

# %%
df['Date'].max()-df['Date'].min()
# Out:
# Timedelta('2191 days 00:00:00')

# %%
df[df['Open']>20]
# Out:
#                     Date    Open    High     Low   Close    Volume    DayWeek
# 0    2015-04-01 16:00:00   40.60   40.76   40.31   40.72  36865322  Wednesday
# 1    2015-04-02 16:00:00   40.66   40.74   40.12   40.29  37487476  Wednesday
# 2    2015-04-06 16:00:00   40.34   41.78   40.18   41.55  39223692  Wednesday
# 3    2015-04-07 16:00:00   41.61   41.91   41.31   41.53  28809375  Wednesday
# 4    2015-04-08 16:00:00   41.48   41.69   41.04   41.42  24753438  Wednesday
# ...                  ...     ...     ...     ...     ...       ...        ...
# 1506 2021-03-25 16:00:00  235.30  236.94  231.57  232.34  34061853  Wednesday
# 1507 2021-03-26 16:00:00  231.55  236.71  231.55  236.48  25479853  Wednesday
# 1508 2021-03-29 16:00:00  236.59  236.80  231.88  235.24  25227455  Wednesday
# 1509 2021-03-30 16:00:00  233.53  233.85  231.10  231.85  24792012  Wednesday
# 1510 2021-03-31 16:00:00  232.91  239.10  232.39  235.77  43623471  Wednesday
#
# [1511 rows x 7 columns]

# %%
df[df['Date']>'2020']
# Out:
#                     Date    Open    High     Low   Close    Volume    DayWeek
# 1197 2020-01-02 16:00:00  158.78  160.73  158.33  160.62  22634546  Wednesday
# 1198 2020-01-03 16:00:00  158.32  159.95  158.06  158.62  21121681  Wednesday
# 1199 2020-01-06 16:00:00  157.08  159.10  156.51  159.03  20826702  Wednesday
# 1200 2020-01-07 16:00:00  159.32  159.67  157.32  157.58  21881740  Wednesday
# 1201 2020-01-08 16:00:00  158.93  160.80  157.95  160.09  27762026  Wednesday
# ...                  ...     ...     ...     ...     ...       ...        ...
# 1506 2021-03-25 16:00:00  235.30  236.94  231.57  232.34  34061853  Wednesday
# 1507 2021-03-26 16:00:00  231.55  236.71  231.55  236.48  25479853  Wednesday
# 1508 2021-03-29 16:00:00  236.59  236.80  231.88  235.24  25227455  Wednesday
# 1509 2021-03-30 16:00:00  233.53  233.85  231.10  231.85  24792012  Wednesday
# 1510 2021-03-31 16:00:00  232.91  239.10  232.39  235.77  43623471  Wednesday
#
# [314 rows x 7 columns]

# %%
df[(df['Date']>'2020') & (df['Date']<'2021')]
# Out:
#                     Date    Open    High     Low   Close    Volume    DayWeek
# 1197 2020-01-02 16:00:00  158.78  160.73  158.33  160.62  22634546  Wednesday
# 1198 2020-01-03 16:00:00  158.32  159.95  158.06  158.62  21121681  Wednesday
# 1199 2020-01-06 16:00:00  157.08  159.10  156.51  159.03  20826702  Wednesday
# 1200 2020-01-07 16:00:00  159.32  159.67  157.32  157.58  21881740  Wednesday
# 1201 2020-01-08 16:00:00  158.93  160.80  157.95  160.09  27762026  Wednesday
# ...                  ...     ...     ...     ...     ...       ...        ...
# 1445 2020-12-24 13:00:00  221.42  223.61  221.20  222.75  10550572  Wednesday
# 1446 2020-12-28 16:00:00  224.45  226.03  223.02  224.96  17933496  Wednesday
# 1447 2020-12-29 16:00:00  226.31  227.18  223.58  224.15  17403213  Wednesday
# 1448 2020-12-30 16:00:00  225.23  225.63  221.47  221.68  20272337  Wednesday
# 1449 2020-12-31 16:00:00  221.70  223.00  219.68  222.42  20942132  Wednesday
#
# [253 rows x 7 columns]

# %%
df.set_index('Date',inplace=True)

# %%
df.loc['2020']
# Out:
#                        Open    High     Low   Close    Volume    DayWeek
# Date
# 2020-01-02 16:00:00  158.78  160.73  158.33  160.62  22634546  Wednesday
# 2020-01-03 16:00:00  158.32  159.95  158.06  158.62  21121681  Wednesday
# 2020-01-06 16:00:00  157.08  159.10  156.51  159.03  20826702  Wednesday
# 2020-01-07 16:00:00  159.32  159.67  157.32  157.58  21881740  Wednesday
# 2020-01-08 16:00:00  158.93  160.80  157.95  160.09  27762026  Wednesday
# ...                     ...     ...     ...     ...       ...        ...
# 2020-12-24 13:00:00  221.42  223.61  221.20  222.75  10550572  Wednesday
# 2020-12-28 16:00:00  224.45  226.03  223.02  224.96  17933496  Wednesday
# 2020-12-29 16:00:00  226.31  227.18  223.58  224.15  17403213  Wednesday
# 2020-12-30 16:00:00  225.23  225.63  221.47  221.68  20272337  Wednesday
# 2020-12-31 16:00:00  221.70  223.00  219.68  222.42  20942132  Wednesday
#
# [253 rows x 6 columns]

# %%
df['2020-2':'2020-3']
# Out:
#                        Open    High     Low   Close    Volume    DayWeek
# Date
# 2020-02-03 16:00:00  170.43  174.50  170.40  174.38  30149052  Wednesday
# 2020-02-04 16:00:00  177.14  180.64  176.31  180.12  36433339  Wednesday
# 2020-02-05 16:00:00  184.03  184.20  178.41  179.90  39186324  Wednesday
# 2020-02-06 16:00:00  180.97  183.82  180.06  183.63  27751381  Wednesday
# 2020-02-07 16:00:00  182.85  185.63  182.48  183.89  33529074  Wednesday
# 2020-02-10 16:00:00  183.58  188.84  183.25  188.70  35844267  Wednesday
# 2020-02-11 16:00:00  190.65  190.70  183.50  184.44  53159906  Wednesday
# 2020-02-12 16:00:00  185.58  185.85  181.85  184.71  47062921  Wednesday
# 2020-02-13 16:00:00  183.08  186.23  182.87  183.71  35295834  Wednesday
# 2020-02-14 16:00:00  183.25  185.41  182.65  185.35  23149516  Wednesday
# 2020-02-18 16:00:00  185.61  187.70  185.50  187.23  27853113  Wednesday
# 2020-02-19 16:00:00  188.06  188.18  186.47  187.28  29997471  Wednesday
# ...

# %%
df.loc['2020-2']['Close'].mean()
# Out:
# 178.71947368421053

# %%
df.loc['2020-2']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#M meaning of month
df['High'].resample('M').max()
# Out:
# Date
# 2015-04-30     49.54
# 2015-05-31     48.91
# 2015-06-30     47.77
# 2015-07-31     47.40
# 2015-08-31     48.41
#                ...
# 2020-11-30    228.12
# 2020-12-31    227.18
# 2021-01-31    242.64
# 2021-02-28    246.13
# 2021-03-31    241.05
# Freq: M, Name: High, Length: 72, dtype: float64

# %%
#W meaning of week
df['High'].resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('M').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2015-04-30   43.070952   43.736667   42.870952   43.466667  4.164453e+07
# 2015-05-31   47.590000   47.977000   47.185500   47.530000  3.165364e+07
# 2015-06-30   46.104545   46.466364   45.679545   45.964091  3.022061e+07
# 2015-07-31   45.484545   46.013182   45.145455   45.611818  3.297537e+07
# 2015-08-31   45.541905   46.120476   44.933810   45.506667  3.697607e+07
# ...                ...         ...         ...         ...           ...
# 2020-11-30  214.210000  216.458000  211.854000  214.139000  2.867372e+07
# 2020-12-31  217.612727  219.528636  216.009091  217.963182  2.702596e+07
# 2021-01-31  221.942632  224.572105  219.524211  221.975263  3.410516e+07
# 2021-02-28  239.622105  241.967368  237.451579  240.066842  2.584115e+07
# 2021-03-31  233.826522  236.289565  231.506087  233.674348  3.152094e+07
#
# [72 rows x 5 columns]

# %%
#I want calculate mean for open,max...etc
df.resample('M').agg({'Open':'mean','High':'max','Low':'min','Volume':'sum'})
# Out:
#                   Open    High     Low     Volume
# Date
# 2015-04-30   43.070952   49.54   40.12  874535095
# 2015-05-31   47.590000   48.91   46.02  633072750
# 2015-06-30   46.104545   47.77   43.94  664853340
# 2015-07-31   45.484545   47.40   43.32  725458102
# 2015-08-31   45.541905   48.41   39.72  776497465
# ...                ...     ...     ...        ...
# 2020-11-30  214.210000  228.12  200.12  573474483
# 2020-12-31  217.612727  227.18  209.11  594571054
# 2021-01-31  221.942632  242.64  211.94  647998091
# 2021-02-28  239.622105  246.13  227.88  490981822
# 2021-03-31  233.826522  241.05  224.26  724981506
#
# [72 rows x 4 columns]
